# %% [markdown]
# <a href="https://colab.research.google.com/github/sccgmonk/data/blob/main/testcast2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel('/content/newcar67.xls',sheet_name=list(range(0,5)),header=3)

# %%
for n in range (0,5):
  #rename column
    df[n].rename(columns={'ยี่ห้อรถ':'brand',
                    'รุ่นรถ':'model',
                   'จำนวนรถ':'Number_of_Newcar'},inplace=True)
    #create column type_reg
    df[n]['Type_register']=df[n].apply(lambda x:x['brand'] if np.isnan(x['รวมยี่ห้อ']) else np.nan,axis=1)
      #add fillna column type and brand
    df[n]['Type_register']=df[n]['Type_register'].fillna(method='pad')
    df[n]['brand']=df[n]['brand'].fillna(method='pad')
    #drop column Nan
    df[n]=df[n].dropna(subset=['model']).reset_index(drop=True)
    #change type odj to int
    df[n]['Number_of_Newcar']=df[n]['Number_of_Newcar'].astype(int)
    df[n].set_index('brand', inplace=True)
    df[n].drop(['รวมยี่ห้อ'],axis=1,inplace=True)
    #df[n]['Year'] =df[n].apply(lambda x: '2024' if pd.notna(x['model']) else pd.isna(x['model']), axis=1)
    #create column date
    df[n]['DATE']=df[n].apply(lambda x:'2024'+'-'+ str(n+1) if pd.notna(x['model']) else pd.isna(x['model']), axis=1)
    df[n]['DATE']=pd.to_datetime(df[n]['DATE'] )










    #df[n]['Month'] = df[n]['Month'].month_name()



    #df[n]['DATE']=df[n]['Year'].astype(str)+'-'+df[n]['Month'].astype(str)

    #df[n]['DATE']=pd.to_datetime(df[n]['DATE'] )
    #df[n].drop(['Year','Month'],axis=1,inplace=True)

# %%
df[0].head()
# Out:
#                                   model  Number_of_Newcar  \
# brand
# ASTON MARTIN           VANTAGE F1 COUPE                 1
# AUDI               A4 40 TFSI S line IB                 2
# AUDI          A4 AV 45 TFSI q S line IB                 1
# AUDI                                 A5                 1
# AUDI               A5 CP 40 TFSI S line                13
#
#                                                  Type_register       DATE
# brand
# ASTON MARTIN  ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
# AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
# AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
# AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
# AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01

# %%
df[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1414 entries, ASTON MARTIN to YAMAHA
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             1414 non-null   object
#  1   Number_of_Newcar  1414 non-null   int64
#  2   Type_register     1414 non-null   object
#  3   DATE              1414 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 55.2+ KB

# %%
dt=pd.concat(df,keys=range(0,5))

# %%
dt.shape
# Out:
# (7086, 4)

# %%
dt.isnull().sum()
dt.isna().sum()
# Out:
# model               0
# Number_of_Newcar    0
# Type_register       0
# DATE                0
# dtype: int64

# %%
pd.isna(dt).sum()
# Out:
# model               0
# Number_of_Newcar    0
# Type_register       0
# DATE                0
# dtype: int64

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 7086 entries, (0, 'ASTON MARTIN') to (4, 'YAMAHA')
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             7086 non-null   object
#  1   Number_of_Newcar  7086 non-null   int64
#  2   Type_register     7086 non-null   object
#  3   DATE              7086 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 252.6+ KB

# %%
dt.head()
# Out:
#                                     model  Number_of_Newcar  \
#   brand
# 0 ASTON MARTIN           VANTAGE F1 COUPE                 1
#   AUDI               A4 40 TFSI S line IB                 2
#   AUDI          A4 AV 45 TFSI q S line IB                 1
#   AUDI                                 A5                 1
#   AUDI               A5 CP 40 TFSI S line                13
#
#                                                    Type_register       DATE
#   brand
# 0 ASTON MARTIN  ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01

# %%
dt['เดือน'] = dt['DATE'].dt.month_name()

dt['YEARS'] = df['DATE'].dt.year()

# %%
dt.head()
# Out:
#                                     model  Number_of_Newcar  \
#   brand
# 0 ASTON MARTIN           VANTAGE F1 COUPE                 1
#   AUDI               A4 40 TFSI S line IB                 2
#   AUDI          A4 AV 45 TFSI q S line IB                 1
#   AUDI                                 A5                 1
#   AUDI               A5 CP 40 TFSI S line                13
#
#                                                    Type_register       DATE  \
#   brand
# 0 ASTON MARTIN  ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#   AUDI          ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน 2024-01-01
#
#                   เดือน
#   brand
# 0 ASTON MARTIN  January
#   AUDI          January
#   AUDI          January
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 7086 entries, (0, 'ASTON MARTIN') to (4, 'YAMAHA')
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             7086 non-null   object
#  1   Number_of_Newcar  7086 non-null   int64
#  2   Type_register     7086 non-null   object
#  3   DATE              7086 non-null   datetime64[ns]
#  4   เดือน             7086 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 308.0+ KB

# %%
dt.reset_index(inplace=True)
dt.set_index('DATE',inplace=True)

# %%
dt
# Out:
#             level_0         brand                      model  \
# DATE
# 2024-01-01        0  ASTON MARTIN           VANTAGE F1 COUPE
# 2024-01-01        0          AUDI       A4 40 TFSI S line IB
# 2024-01-01        0          AUDI  A4 AV 45 TFSI q S line IB
# 2024-01-01        0          AUDI                         A5
# 2024-01-01        0          AUDI       A5 CP 40 TFSI S line
# ...             ...           ...                        ...
# 2024-05-01        4         HONDA                     SCOOPY
# 2024-05-01        4         HONDA                   WAVE110i
# 2024-05-01        4         HONDA                   WAVE125i
# 2024-05-01        4        YAMAHA                       FINN
# 2024-05-01        4        YAMAHA               GRAND FILANO
#
#             Number_of_Newcar                                     Type_register
# DATE
# 2024-01-01                 1  ประเภทรถ : รย. 1 รถยนต์นั่งส่วนบุคคลไม่เกิน 7 คน
# ...

# %%
dt.drop(['level_0'],axis=1,inplace=True)

# %%
dt
# Out:
#                    brand                      model  Number_of_Newcar  \
# DATE
# 2024-01-01  ASTON MARTIN           VANTAGE F1 COUPE                 1
# 2024-01-01          AUDI       A4 40 TFSI S line IB                 2
# 2024-01-01          AUDI  A4 AV 45 TFSI q S line IB                 1
# 2024-01-01          AUDI                         A5                 1
# 2024-01-01          AUDI       A5 CP 40 TFSI S line                13
# ...                  ...                        ...               ...
# 2024-05-01         HONDA                     SCOOPY                 1
# 2024-05-01         HONDA                   WAVE110i                14
# 2024-05-01         HONDA                   WAVE125i                35
# 2024-05-01        YAMAHA                       FINN                 5
# 2024-05-01        YAMAHA               GRAND FILANO                 2
#
#                                                Type_register
# DATE
# ...

# %%
dt.to_excel('รถจดทะเบียนใหม่มค-พค.xlsx')

# %%
dt.to_csv('รถจดทะเบียนใหม่มค-พค.csv')
